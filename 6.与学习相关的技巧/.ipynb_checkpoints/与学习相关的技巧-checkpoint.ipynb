# %% [markdown]
# # 与学习相关的技巧

# %% [markdown]
# ## 参数的更新

# %% [markdown]
# ### SGD

# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
## 伪代码
# network = TwoLayerNet(...)
# optimizer = SGD()
# for i in range(10000):
#     ...
#     x_batch, t_batch = get_mini_batch(...) # mini-batch
#     grads = network.gradient(x_batch, t_batch)
#     params = network.params
#     optimizer.update(params, grads)
#     ...

# %% [markdown]
# ### Momentum

# %%
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
    
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
        for key, val in params.items():
            self.v[key] = np.zeros_like(val)
        for key in params.keys():
            self.v[key] = self.momentum*self.v[key] - self.lr*grads[key]
            params[key] += self.v[key]

# %% [markdown]
# ### AdaGrad

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
    
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
        for key, val in params.items():
            self.h[key] = np.zeros_like(val)
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %% [markdown]
# ## 权重的初始值

# %% [markdown]
# ### 隐藏层的激活层的分分布

# %%
import numpy as np
import matplotlib.pyplot as plt
    
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100) # 1000个数据
node_num = 100 # 各隐藏层的节点（神经元）数
hidden_layer_size = 5 # 隐藏层有5层
activations = {} # 激活值的结果保存在这里

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
    w = np.random.randn(node_num, node_num) * 1 # 标准差为1的高斯分布
    z = np.dot(x, w)
    a = sigmoid(z) # sigmoid函数
    activations[i] = a

# %%
# 绘制直方图
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
    
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100) # 1000个数据
node_num = 100 # 各隐藏层的节点（神经元）数
hidden_layer_size = 5 # 隐藏层有5层
activations = {} # 激活值的结果保存在这里

# w = np.random.randn(node_num, node_num) * 1 # 标准差为1的高斯分布
# w = np.random.randn(node_num, node_num) * 0.01 # 标准差为0.01的高斯分布

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
    w = np.random.randn(node_num, node_num) * 0.01 # 标准差为0.01的高斯分布
    z = np.dot(x, w)
    a = sigmoid(z) # sigmoid函数
    activations[i] = a

# 绘制直方图
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
    
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100) # 1000个数据
node_num = 100 # 各隐藏层的节点（神经元）数
hidden_layer_size = 5 # 隐藏层有5层
activations = {} # 激活值的结果保存在这里

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
    node_num = 100 # 前一层的节点数
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num) # Xavier初始值
    z = np.dot(x, w)
    a = sigmoid(z) # sigmoid函数
    activations[i] = a

# 绘制直方图
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %% [markdown]
# ### ReLU的权重初始值

# %%
import numpy as np
import matplotlib.pyplot as plt
    
def ReLU(x):
    return np.maximum(0,x)

x = np.random.randn(1000, 100) # 1000个数据
node_num = 100 # 各隐藏层的节点（神经元）数
hidden_layer_size = 5 # 隐藏层有5层
activations = {} # 激活值的结果保存在这里


for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
    w = np.random.randn(node_num, node_num)* 0.01 # 标准差为0.01的高斯分布
    z = np.dot(x, w)
    a = ReLU(z) # ReLU函数
    activations[i] = a

# 绘制直方图
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
    
def ReLU(x):
    return np.maximum(0,x)

x = np.random.randn(1000, 100) # 1000个数据
node_num = 100 # 各隐藏层的节点（神经元）数
hidden_layer_size = 5 # 隐藏层有5层
activations = {} # 激活值的结果保存在这里

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
    node_num = 100 # 前一层的节点数
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num) # Xavier初始值
    z = np.dot(x, w)
    a = ReLU(z) # ReLU函数
    activations[i] = a

# 绘制直方图
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
    
def ReLU(x):
    return np.maximum(0,x)

x = np.random.randn(1000, 100) # 1000个数据
node_num = 100 # 各隐藏层的节点（神经元）数
hidden_layer_size = 5 # 隐藏层有5层
activations = {} # 激活值的结果保存在这里

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
    node_num = 100 # 前一层的节点数
    w = np.random.randn(node_num, node_num) * np.sqrt(2 / node_num) # 标准差为 根号2/n 的高斯分布 -- He初始值
    z = np.dot(x, w)
    a = ReLU(z) # ReLU函数
    activations[i] = a

# 绘制直方图
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %% [markdown]
# ## 正则化

# %% [markdown]
# ### 过拟合

# %%
import sys, os
sys.path.append(os.pardir)
import numpy as np
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD
import matplotlib.pyplot as plt


(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)
# 为了再现过拟合，减少学习数据
x_train = x_train[:300]
t_train = t_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = SGD(lr=0.01) # 用学习率为0.01的SGD更新参数
max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100
train_loss_list = []
train_acc_list = []
test_acc_list = []
iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0
for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
            
# Plot the training and test accuracy
plt.plot(train_acc_list, label='Training Accuracy')
plt.plot(test_acc_list, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Dropout

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
    
    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)
    
    def backward(self, dout):
        return dout * self.mask

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

x_train = x_train[:300]
t_train = t_train[:300]

use_dropout = True  
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list


markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.297897448444995
# === epoch:1, train acc:0.12666666666666668, test acc:0.1502 ===
# train loss:2.298129623872443
# train loss:2.2816498045624387
# train loss:2.306000467934234
# === epoch:2, train acc:0.12666666666666668, test acc:0.1497 ===
# train loss:2.2959896440481073
# train loss:2.3079988493086594
# train loss:2.296351597498854
# === epoch:3, train acc:0.13, test acc:0.1522 ===
# train loss:2.284817250494324
# train loss:2.2892482945495014
# train loss:2.2900989632174547
# === epoch:4, train acc:0.13, test acc:0.1504 ===
# train loss:2.2992971474688897
# train loss:2.2938643398598573
# train loss:2.2972979933929936
# === epoch:5, train acc:0.14, test acc:0.1456 ===
# train loss:2.2920056693290123
# train loss:2.2818174927256307
# train loss:2.2698467108913176
# === epoch:6, train acc:0.14, test acc:0.1454 ===
# train loss:2.2890424646356857
# train loss:2.3032963319125654
# train loss:2.267770321004549
# === epoch:7, train acc:0.15, test acc:0.1496 ===
# train loss:2.296040657252563
# train loss:2.036976235133704
# train loss:2.06122754121804
# train loss:2.0860094526816924
# === epoch:160, train acc:0.52, test acc:0.4297 ===
# train loss:2.0061462251585604
# train loss:1.9391807973684145
# train loss:1.9582342632265883
# === epoch:161, train acc:0.5, test acc:0.4353 ===
# train loss:1.9824750861124565
# train loss:1.9538281107477702
# train loss:1.9712236786407553
# === epoch:162, train acc:0.5166666666666667, test acc:0.4407 ===
# train loss:1.9851814247554076
# train loss:1.947842458323003
# train loss:1.9540163242959137
# === epoch:163, train acc:0.5066666666666667, test acc:0.4386 ===
# train loss:1.9639251771954613
# train loss:1.8833858302948727
# train loss:2.0023713777039363
# === epoch:164, train acc:0.5066666666666667, test acc:0.4406 ===
# train loss:1.8948027762009843
# train loss:2.0108755757635923
# train loss:1.936352522900572
# === epoch:165, train acc:0.5066666666666667, test acc:0.4433 ===
# train loss:1.9942265169532691
# train loss:1.9742930746361962
# train loss:1.9549297773030099
# === epoch:166, train acc:0.5166666666666667, test acc:0.452 ===
# train loss:1.9884010350537473
# train loss:1.9823699070411527
# train loss:1.9720249953920383
# === epoch:167, train acc:0.53, test acc:0.4639 ===
# train loss:1.9484303100986886
# train loss:1.935327706752161
# train loss:1.938266338614979
# === epoch:168, train acc:0.53, test acc:0.4684 ===
# train loss:1.9730481046471888
# train loss:1.981405363590039
# train loss:1.9682965161441475
# === epoch:169, train acc:0.5333333333333333, test acc:0.4713 ===
# train loss:1.9392041943712028
# train loss:1.9523462592962377
# train loss:1.864468118547333
# === epoch:170, train acc:0.5366666666666666, test acc:0.4722 ===
# train loss:1.9091149407228303
# train loss:1.9497396534420535
# train loss:1.905808855504001
# === epoch:171, train acc:0.5266666666666666, test acc:0.4705 ===
# train loss:1.8979176711782189
# train loss:1.8879070843393089
# train loss:1.9267354682669096
# === epoch:172, train acc:0.53, test acc:0.4687 ===
# train loss:1.8867890711266653
# train loss:1.9396416943097503
# train loss:1.9064164884043955
# === epoch:173, train acc:0.5366666666666666, test acc:0.47 ===
# train loss:1.9305592789894115
# train loss:1.9550833392927973
# train loss:1.889992153015394
# === epoch:174, train acc:0.54, test acc:0.4744 ===
# train loss:1.933582744229045
# train loss:1.8864389898490734
# train loss:1.8292102112300903
# === epoch:175, train acc:0.5366666666666666, test acc:0.4728 ===
# train loss:1.8220364767383017
# train loss:1.947026813121391
# train loss:1.8955095408001836
# === epoch:176, train acc:0.5333333333333333, test acc:0.472 ===
# train loss:1.9245811172381477
# train loss:1.8015623040356783
# train loss:1.8783557552250303
# === epoch:177, train acc:0.5333333333333333, test acc:0.4678 ===
# train loss:1.9549344662477928
# train loss:1.9145656740948558
# train loss:1.9032177685481155
# === epoch:178, train acc:0.5466666666666666, test acc:0.4692 ===
# train loss:1.9063897688526814
# train loss:1.8577922648937428
# train loss:1.8988187533111434
# === epoch:179, train acc:0.5533333333333333, test acc:0.4729 ===
# train loss:1.9376956448747764
# train loss:1.8589609009186288
# train loss:1.8825978273584603
# === epoch:180, train acc:0.55, test acc:0.4765 ===
# train loss:1.8529084176934898
# train loss:1.8404284163287732
# train loss:1.8677642633667049
# === epoch:181, train acc:0.5466666666666666, test acc:0.4777 ===
# train loss:1.872924142087134
# train loss:1.855837552087141
# train loss:1.8762059850478368
# === epoch:182, train acc:0.54, test acc:0.4771 ===
# train loss:1.8454523375177785
# train loss:1.8998785173896138
# train loss:1.789177793764055
# === epoch:183, train acc:0.55, test acc:0.4769 ===
# train loss:1.8205398923793572
# train loss:1.838336526697619
# train loss:1.8513595044002085
# === epoch:184, train acc:0.5466666666666666, test acc:0.4789 ===
# train loss:1.7765954342488728
# train loss:1.8363725871880119
# train loss:1.9030661033168386
# === epoch:185, train acc:0.55, test acc:0.481 ===
# train loss:1.8998169767253663
# train loss:1.7846147157005503
# train loss:1.834622326926877
# === epoch:186, train acc:0.55, test acc:0.4859 ===
# train loss:1.8856341638870384
# train loss:1.8539085948520702
# train loss:1.839887273344519
# === epoch:187, train acc:0.5466666666666666, test acc:0.4856 ===
# train loss:1.8210597840032525
# train loss:1.7660077643806509
# train loss:1.8190977523832788
# === epoch:188, train acc:0.54, test acc:0.4878 ===
# train loss:1.8234277839820212
# train loss:1.813618718546339
# train loss:1.8236985841440374
# === epoch:189, train acc:0.54, test acc:0.4859 ===
# train loss:1.842680440063463
# train loss:1.8063699654128058
# train loss:1.8820939476594845
# === epoch:190, train acc:0.5366666666666666, test acc:0.4868 ===
# train loss:1.721216189518054
# train loss:1.864373778125648
# train loss:1.8137428264924753
# === epoch:191, train acc:0.5433333333333333, test acc:0.4872 ===
# train loss:1.795154777594114
# train loss:1.7353849655601281
# train loss:1.8203994012952316
# === epoch:192, train acc:0.55, test acc:0.4886 ===
# train loss:1.8657726047525847
# train loss:1.7993162335303814
# train loss:1.8089952984756985
# === epoch:193, train acc:0.55, test acc:0.491 ===
# train loss:1.9201479108248747
# train loss:1.813421522663078
# train loss:1.754793749569036
# === epoch:194, train acc:0.55, test acc:0.4951 ===
# train loss:1.7817929355060358
# train loss:1.7262287640111373
# train loss:1.779809411616462
# === epoch:195, train acc:0.55, test acc:0.4992 ===
# train loss:1.8170467752836605
# train loss:1.8429998971804937
# train loss:1.7237209960837052
# === epoch:196, train acc:0.5533333333333333, test acc:0.4982 ===
# train loss:1.7746685647900693
# train loss:1.6744821357824575
# train loss:1.7876679660244406
# === epoch:197, train acc:0.5566666666666666, test acc:0.4978 ===
# train loss:1.7673901488751123
# train loss:1.7980074067894032
# train loss:1.8203218521124682
# === epoch:198, train acc:0.5566666666666666, test acc:0.499 ===
# train loss:1.7728704824375034
# train loss:1.6560704510585231
# train loss:1.730385293643401
# === epoch:199, train acc:0.5566666666666666, test acc:0.4991 ===
# train loss:1.7245451350991419
# train loss:1.823413705272812
# train loss:1.692776106528396
# === epoch:200, train acc:0.56, test acc:0.496 ===
# train loss:1.714973273683774
# train loss:1.8071462259409667
# train loss:1.696172082493633
# === epoch:201, train acc:0.5566666666666666, test acc:0.4919 ===
# train loss:1.7149302260349961
# train loss:1.765466718880264
# train loss:1.635333652685131
# === epoch:202, train acc:0.5666666666666667, test acc:0.4923 ===
# train loss:1.6771452945339846
# train loss:1.6454474201159976
# train loss:1.687403709630337
# === epoch:203, train acc:0.5533333333333333, test acc:0.4854 ===
# train loss:1.6987505877500246
# train loss:1.6932082055399338
# train loss:1.6696159101435666
# === epoch:204, train acc:0.55, test acc:0.4823 ===
# train loss:1.6918707655161114
# train loss:1.713391547998238
# train loss:1.6123144456716838
# === epoch:205, train acc:0.5533333333333333, test acc:0.485 ===
# train loss:1.6630961399331468
# train loss:1.696867420232511
# train loss:1.6576227596988673
# === epoch:206, train acc:0.5566666666666666, test acc:0.4836 ===
# train loss:1.66817947161224
# train loss:1.6207315259739121
# train loss:1.6589596971145653
# === epoch:207, train acc:0.5466666666666666, test acc:0.4835 ===
# train loss:1.65163765026656
# train loss:1.6936359468489735
# train loss:1.6623726427827363
# === epoch:208, train acc:0.55, test acc:0.4843 ===
# train loss:1.6908617131964698
# train loss:1.6108430455029366
# train loss:1.6639706827973324
# === epoch:209, train acc:0.5466666666666666, test acc:0.4894 ===
# train loss:1.6724858505351614
# train loss:1.6567781795106549
# train loss:1.7182851698423411
# === epoch:210, train acc:0.55, test acc:0.4906 ===
# train loss:1.5374152168956332
# train loss:1.6058981739968692
# train loss:1.6196241518852867
# === epoch:211, train acc:0.55, test acc:0.4843 ===
# train loss:1.694781019294544
# train loss:1.6375746134757427
# train loss:1.6402738716214569
# === epoch:212, train acc:0.5466666666666666, test acc:0.482 ===
# train loss:1.5876033151941409
# train loss:1.7215396262024927
# train loss:1.6346716574357987
# === epoch:213, train acc:0.5533333333333333, test acc:0.4869 ===
# train loss:1.6621721694600406
# train loss:1.7978703870177466
# train loss:1.6337041817681694
# === epoch:214, train acc:0.5566666666666666, test acc:0.4894 ===
# train loss:1.6671906396994864
# train loss:1.672016781681014
# train loss:1.6043100642232162
# === epoch:215, train acc:0.5566666666666666, test acc:0.489 ===
# train loss:1.5980423926477423
# train loss:1.6869290172666769
# train loss:1.7090232385031794
# === epoch:216, train acc:0.56, test acc:0.4867 ===
# train loss:1.679221733771086
# train loss:1.614317348052773
# train loss:1.7017591227606976
# === epoch:217, train acc:0.5633333333333334, test acc:0.4903 ===
# train loss:1.5870409250491617
# train loss:1.608386132128318
# train loss:1.5446215360820106
# === epoch:218, train acc:0.5566666666666666, test acc:0.4847 ===
# train loss:1.5659610355025066
# train loss:1.44311832346483
# train loss:1.5686405739221934
# === epoch:219, train acc:0.5533333333333333, test acc:0.4887 ===
# train loss:1.52422093737942
# train loss:1.6576317622374126
# train loss:1.5415636523549008
# === epoch:220, train acc:0.5566666666666666, test acc:0.4924 ===
# train loss:1.4948404978005263
# train loss:1.547597251456315
# train loss:1.550243287082428
# === epoch:221, train acc:0.5633333333333334, test acc:0.4936 ===
# train loss:1.5836536857670223
# train loss:1.5437976066597157
# train loss:1.516796358881191
# === epoch:222, train acc:0.56, test acc:0.4935 ===
# train loss:1.598182111718682
# train loss:1.6568939483215273
# train loss:1.6489473607019867
# === epoch:223, train acc:0.56, test acc:0.4945 ===
# train loss:1.620631384769327
# train loss:1.4797745915514844
# train loss:1.559082967718311
# === epoch:224, train acc:0.56, test acc:0.4937 ===
# train loss:1.530910541744715
# === epoch:246, train acc:0.5466666666666666, test acc:0.4768 ===
# train loss:1.3810161762113764
# train loss:1.3430456361117495
# train loss:1.4416956383916553
# === epoch:247, train acc:0.5433333333333333, test acc:0.4728 ===
# train loss:1.440250252215951
# train loss:1.347779727365987
# train loss:1.3425922289723349
# === epoch:248, train acc:0.5433333333333333, test acc:0.4733 ===
# train loss:1.4167980524947976
# train loss:1.3528986930000932
# train loss:1.3092226942728664
# === epoch:249, train acc:0.54, test acc:0.4731 ===
# train loss:1.3475975554305049
# train loss:1.4344060593042536
# train loss:1.3110478741620575
# === epoch:250, train acc:0.5433333333333333, test acc:0.4759 ===
# train loss:1.291282460925574
# train loss:1.4125431364902294
# train loss:1.319523088948466
# === epoch:251, train acc:0.5433333333333333, test acc:0.4747 ===
# train loss:1.3446797389236445
# train loss:1.3127424602617408
# train loss:1.333922166188244
# === epoch:252, train acc:0.5366666666666666, test acc:0.4738 ===
# train loss:1.4520839594711132
# train loss:1.2539195817849913
# train loss:1.3374182996004125
# === epoch:253, train acc:0.5433333333333333, test acc:0.4718 ===
# train loss:1.448218727589134
# train loss:1.4176043255939368
# train loss:1.4633846375341646
# === epoch:254, train acc:0.54, test acc:0.4743 ===
# train loss:1.3899453971312161
# train loss:1.3972230264021115
# train loss:1.323388346076016
# === epoch:255, train acc:0.54, test acc:0.4794 ===
# train loss:1.3137853426283377
# train loss:1.4103358838862408
# train loss:1.3278496784316645
# === epoch:256, train acc:0.5433333333333333, test acc:0.4846 ===
# train loss:1.3487648810941895
# train loss:1.2918667165960571
# train loss:1.4797802327906207
# === epoch:257, train acc:0.56, test acc:0.4941 ===
# train loss:1.386552441414936
# train loss:1.352400616748258
# train loss:1.3432191441427213
# === epoch:258, train acc:0.55, test acc:0.4902 ===
# train loss:1.2800680264395856
# train loss:1.3549344750485834
# train loss:1.3801131390110615
# === epoch:259, train acc:0.55, test acc:0.4857 ===
# train loss:1.2608966975740707
# train loss:1.3672463589136847
# train loss:1.4880335107647873
# === epoch:260, train acc:0.55, test acc:0.4821 ===
# train loss:1.4080079241802226
# train loss:1.2642784998277963
# train loss:1.3807085951585198
# === epoch:261, train acc:0.56, test acc:0.4818 ===
# train loss:1.3930171797588264
# train loss:1.2840555905148008
# train loss:1.309539805124871
# === epoch:262, train acc:0.55, test acc:0.4874 ===
# train loss:1.2369147089924697
# train loss:1.291035679077178
# train loss:1.3125080673031126
# === epoch:263, train acc:0.5433333333333333, test acc:0.4798 ===
# train loss:1.2942124766586678
# train loss:1.29915879404183
# train loss:1.306292986783288
# === epoch:264, train acc:0.5566666666666666, test acc:0.487 ===
# train loss:1.2969129581896441
# train loss:1.2482037773090702
# train loss:1.3370543349440767
# === epoch:265, train acc:0.5533333333333333, test acc:0.4899 ===
# train loss:1.2629522320293878
# train loss:1.533425794152545
# train loss:1.3836245990102976
# === epoch:266, train acc:0.5533333333333333, test acc:0.4901 ===
# train loss:1.3632190164248223
# train loss:1.2459485701296167
# train loss:1.2340617867993406
# === epoch:267, train acc:0.5466666666666666, test acc:0.485 ===
# train loss:1.1250242876824492
# train loss:1.3293193939394283
# === epoch:289, train acc:0.6433333333333333, test acc:0.5427 ===
# train loss:1.1826933728655853
# train loss:1.1765933184307682
# train loss:1.2049058651251696
# === epoch:290, train acc:0.6366666666666667, test acc:0.5325 ===
# train loss:1.197260104692167
# train loss:1.245584263840094
# train loss:1.1668994940122768
# === epoch:291, train acc:0.6233333333333333, test acc:0.5264 ===
# train loss:1.2000165126897737
# train loss:1.2936071173475867
# train loss:1.206364811946755
# === epoch:292, train acc:0.65, test acc:0.5373 ===
# train loss:1.0985483827320208
# train loss:1.147344005204839
# train loss:1.2490382383479344
# === epoch:293, train acc:0.6566666666666666, test acc:0.5362 ===
# train loss:1.0907324751322045
# train loss:1.1902939835613153
# train loss:1.140585884631893
# === epoch:294, train acc:0.66, test acc:0.5433 ===
# train loss:1.061860455559935
# train loss:1.2825394531885386
# train loss:1.183381305738347
# === epoch:295, train acc:0.66, test acc:0.5362 ===
# train loss:1.0928465811709562
# train loss:1.2139461122581474
# train loss:1.1183590046834953
# === epoch:296, train acc:0.6533333333333333, test acc:0.5418 ===
# train loss:1.1423508708682315
# train loss:1.0996610368396516
# train loss:1.119967586532484
# === epoch:297, train acc:0.66, test acc:0.5459 ===
# train loss:1.139773699907205
# train loss:1.1594253407858381
# train loss:1.208905255945199
# === epoch:298, train acc:0.6533333333333333, test acc:0.5455 ===
# train loss:1.0689759820243996
# train loss:1.0711270916137052
# train loss:1.117406460593899
# === epoch:299, train acc:0.6566666666666666, test acc:0.5488 ===
# train loss:1.1859254387966671
# train loss:1.1590429341998365
# train loss:1.2097949926490636
# === epoch:300, train acc:0.6566666666666666, test acc:0.551 ===
# train loss:1.2332540549360274
# train loss:1.1149515991398187
# train loss:1.087404430053559
# === epoch:301, train acc:0.6566666666666666, test acc:0.554 ===
# train loss:1.1180170940573164
# train loss:1.1347192720304011
# =============== Final Test Accuracy ===============
# test acc:0.5549

# %% [markdown]
# ## 超参数的验证

# %% [markdown]
# ### 验证数据

# %%
import sys, os
sys.path.append(os.pardir)
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import shuffle_dataset

(x_train, t_train), (x_test, t_test) = load_mnist()

# 打乱训练数据
x_train, t_train = shuffle_dataset(x_train, t_train)

# 分割验证数据
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %% [markdown]
# ### 超参数最优化的实现

# %%
weight_decay = 10 ** np.random.uniform(-8, -4)
lr = 10 ** np.random.uniform(-6, -2)

# %%
# 导入必要的库
import sys, os
sys.path.append(os.pardir)  # 将父目录添加到sys.path中
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist  # 导入MNIST数据集加载函数
from common.multi_layer_net import MultiLayerNet  # 导入多层神经网络类
from common.util import shuffle_dataset  # 导入数据集打乱函数
from common.trainer import Trainer  # 导入训练器类

# 加载MNIST数据集，并进行归一化
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 只取前500个训练数据和标签进行快速实验
x_train = x_train[:500]
t_train = t_train[:500]

# 设置验证集比例，并计算验证集数量
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)

# 打乱数据集
x_train, t_train = shuffle_dataset(x_train, t_train)

# 分割验证集和训练集
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# 定义训练函数
def __train(lr, weight_decay, epocs=50):
    # 初始化多层神经网络
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    # 初始化训练器
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    # 训练网络
    trainer.train()
    # 返回测试集和训练集的准确率列表
    return trainer.test_acc_list, trainer.train_acc_list

# 设置超参数优化的试验次数
optimization_trial = 100
# 初始化结果字典
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 随机生成学习率和权重衰减超参数
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    
    # 训练网络，并获取验证集和训练集的准确率列表
    val_acc_list, train_acc_list = __train(lr, weight_decay)
    # 打印当前超参数和对应的验证集最后一个epoch的准确率
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    # 构建超参数的字符串键值
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    # 将结果存入字典
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 打印超参数优化结果
print("=========== Hyper-Parameter Optimization Result ===========")
# 设置要绘制的最好的结果数
graph_draw_num = 20
# 设置绘图的列数
col_num = 5
# 计算绘图的行数
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

# 根据验证集最后一个epoch的准确率排序，并绘制前graph_draw_num个结果
for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    # 绘制子图
    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])  # 隐藏部分y轴刻度
    plt.xticks([])  # 隐藏x轴刻度
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)  # 绘制验证集准确率曲线
    plt.plot(x, results_train[key], "--")  # 绘制训练集准确率曲线（虚线）
    i += 1

    if i >= graph_draw_num:
        break

# 显示图形
plt.show()
# Out:
# val acc:0.25 | lr:0.0012702104827559762, weight decay:2.3252452192839348e-06
# val acc:0.09 | lr:3.2794972827882634e-05, weight decay:5.0436863732552945e-05
# val acc:0.43 | lr:0.0022461087916804453, weight decay:8.594261342520517e-07
# val acc:0.1 | lr:4.4957522557354875e-06, weight decay:2.0910147436410357e-08
# val acc:0.11 | lr:1.0979206586226937e-05, weight decay:2.054778749102799e-07
# val acc:0.09 | lr:4.606352876240973e-06, weight decay:2.5189922189755577e-08
# val acc:0.26 | lr:0.002731196764440904, weight decay:2.6742135312311383e-05
# val acc:0.09 | lr:3.625743390453234e-05, weight decay:5.425074443973128e-06
# val acc:0.25 | lr:0.0007738164439105756, weight decay:2.8742171606062984e-08
# val acc:0.16 | lr:0.0005835950488838364, weight decay:2.8534993338342633e-05
# val acc:0.11 | lr:1.269888494719625e-05, weight decay:4.048278521575402e-05
# val acc:0.11 | lr:4.144684245046758e-06, weight decay:2.9350663466333032e-05
# val acc:0.12 | lr:1.903736204032112e-05, weight decay:1.5725359417056066e-08
# val acc:0.85 | lr:0.008159859380032067, weight decay:3.770768908538745e-05
# val acc:0.07 | lr:5.411140449341507e-05, weight decay:6.459937317846914e-08
# val acc:0.43 | lr:0.001409730659481814, weight decay:4.605428397219863e-05
# val acc:0.11 | lr:6.711361441639856e-05, weight decay:7.221305389564186e-08
# val acc:0.06 | lr:6.843633561451204e-06, weight decay:3.024886924474892e-07
# val acc:0.24 | lr:0.0008720181532291953, weight decay:6.657312157183788e-07
# val acc:0.09 | lr:8.214771999334635e-06, weight decay:3.2063675106618843e-05
# val acc:0.59 | lr:0.005022461048300095, weight decay:8.641098943371433e-07
# val acc:0.05 | lr:5.307920894881907e-05, weight decay:7.366210585003135e-05
# val acc:0.09 | lr:6.036209635795328e-06, weight decay:4.180122688678267e-06
# val acc:0.87 | lr:0.009562381761641526, weight decay:9.888997842308008e-07
# val acc:0.08 | lr:6.234688550461149e-06, weight decay:3.5763066468062696e-06
# val acc:0.34 | lr:0.0032034753943218203, weight decay:3.50355207448431e-06
# val acc:0.31 | lr:0.0017631184476883273, weight decay:2.4686074387336505e-07
# val acc:0.1 | lr:5.521935482865115e-06, weight decay:4.8703177977803107e-05
# val acc:0.19 | lr:0.00034907672663511214, weight decay:7.903492478852841e-06
# val acc:0.16 | lr:0.00021236075470929095, weight decay:3.6771301569159206e-07
# val acc:0.14 | lr:4.762948031650386e-05, weight decay:1.2143470699857679e-05
# val acc:0.26 | lr:0.0009190775071233029, weight decay:1.1355696048537932e-06
# val acc:0.1 | lr:1.8676042500954946e-06, weight decay:5.1312949819679475e-06
# val acc:0.06 | lr:2.5078142938839107e-06, weight decay:1.4594967495141196e-07
# val acc:0.07 | lr:3.2789923152766775e-05, weight decay:1.747055581414143e-05
# val acc:0.04 | lr:1.587938715558558e-06, weight decay:2.7451853954990633e-07
# val acc:0.14 | lr:0.00012253202652535696, weight decay:2.670741489972672e-06
# val acc:0.03 | lr:1.2695661158840092e-06, weight decay:1.6318347003382943e-08
# val acc:0.11 | lr:5.8052955389928495e-06, weight decay:1.095983597180711e-05
# val acc:0.07 | lr:1.150948637753692e-05, weight decay:2.5025731151209882e-08
# val acc:0.05 | lr:2.9252027678204483e-05, weight decay:7.890260373991411e-06
# val acc:0.07 | lr:5.755412156022093e-06, weight decay:4.9750643976677105e-06
# val acc:0.08 | lr:0.0003206994262419011, weight decay:1.9751252390818832e-06
# val acc:0.12 | lr:2.9641072220097687e-06, weight decay:2.06129063870687e-05
# val acc:0.08 | lr:0.0001875250530512289, weight decay:1.367568179310382e-07
# val acc:0.53 | lr:0.0046467826100957555, weight decay:3.4146427056790004e-07
# val acc:0.15 | lr:2.5663698231410297e-06, weight decay:6.990908719842534e-07
# val acc:0.77 | lr:0.005053103251681211, weight decay:2.329193083311373e-05
# val acc:0.05 | lr:3.7338019544623396e-06, weight decay:5.553426456381188e-06
# val acc:0.25 | lr:0.0009617004549556207, weight decay:9.206621490974807e-08
# val acc:0.58 | lr:0.0028344929115017648, weight decay:5.2286774556909086e-08
# val acc:0.12 | lr:0.0001292518668379675, weight decay:9.217432051198046e-05
# val acc:0.13 | lr:5.1531863994632164e-06, weight decay:7.5874966476096105e-06
# val acc:0.09 | lr:1.5278109979766688e-06, weight decay:1.399704630462105e-08
# val acc:0.68 | lr:0.00473870164338073, weight decay:1.8893786979773744e-05
# val acc:0.2 | lr:0.0009425815808434606, weight decay:1.5654441958205145e-08
# val acc:0.12 | lr:1.0825818513222313e-05, weight decay:2.884586363654821e-08
# val acc:0.11 | lr:2.798804902895932e-06, weight decay:3.174656871397863e-07
# val acc:0.07 | lr:1.2390407977963624e-05, weight decay:5.1508131368803094e-08
# val acc:0.85 | lr:0.008789937530045805, weight decay:2.710573539592424e-06
# val acc:0.11 | lr:1.4806841399228155e-05, weight decay:7.858916438645804e-07
# val acc:0.08 | lr:1.5834105119711922e-06, weight decay:1.0781665316622343e-08
# val acc:0.13 | lr:2.444995083203795e-05, weight decay:2.081185527586557e-06
# val acc:0.65 | lr:0.005532082802440415, weight decay:1.9216075845887546e-08
# val acc:0.05 | lr:2.3675963998253245e-06, weight decay:1.9076795941025937e-08
# val acc:0.27 | lr:0.0012366070926201238, weight decay:1.0314114635347208e-06
# val acc:0.9 | lr:0.008500891870359345, weight decay:2.56318295699185e-07
# val acc:0.44 | lr:0.001056814192840922, weight decay:8.590142565004911e-07
# val acc:0.12 | lr:0.00015434073166798262, weight decay:3.581467579286782e-08
# val acc:0.12 | lr:5.396016849584996e-06, weight decay:2.438628030363258e-06
# val acc:0.08 | lr:1.130127346889336e-06, weight decay:7.314336951675973e-07
# val acc:0.83 | lr:0.00781913568403434, weight decay:1.311004986589884e-06
# val acc:0.64 | lr:0.00229396456420379, weight decay:4.11549959447376e-05
# val acc:0.34 | lr:0.0015949365227057532, weight decay:1.1087313685091676e-05
# val acc:0.08 | lr:4.218548137512409e-05, weight decay:9.779624108986756e-08
# val acc:0.13 | lr:1.969207544915874e-05, weight decay:8.665864199381968e-08
# val acc:0.13 | lr:3.633994765247303e-05, weight decay:1.8039535205221712e-07
# val acc:0.19 | lr:2.4195023474158458e-06, weight decay:4.4349229529842004e-08
# val acc:0.72 | lr:0.006145959809541509, weight decay:1.629539202515972e-08
# val acc:0.07 | lr:0.0001961313103117747, weight decay:4.798278499301216e-05
# val acc:0.06 | lr:3.1387177282442805e-05, weight decay:2.12642778203765e-05
# val acc:0.74 | lr:0.004293624866585031, weight decay:1.641994001097466e-07
# val acc:0.12 | lr:0.00018779403529018204, weight decay:8.53302593902898e-06
# val acc:0.27 | lr:0.0016082115955413693, weight decay:2.0461234077692447e-05
# val acc:0.2 | lr:0.0001975321113648824, weight decay:3.5407720570080144e-06
# val acc:0.05 | lr:0.00016690930448682768, weight decay:5.941674273034949e-06
# val acc:0.09 | lr:1.2097033324114314e-05, weight decay:7.539876700625126e-08
# val acc:0.06 | lr:4.708942722238802e-05, weight decay:5.970693502831339e-06
# val acc:0.23 | lr:0.0011539003191446985, weight decay:2.2773871712801685e-08
# val acc:0.13 | lr:0.0006252890848313994, weight decay:4.620124197974964e-06
# val acc:0.1 | lr:1.9444516599552086e-05, weight decay:9.500827891475235e-08
# val acc:0.11 | lr:0.0001225426446846014, weight decay:8.94943243601659e-05
# val acc:0.09 | lr:3.7498373425110155e-05, weight decay:6.613594040734339e-05
# val acc:0.11 | lr:1.6191912916118936e-05, weight decay:6.190355327336157e-07
# val acc:0.11 | lr:4.8649539113408925e-05, weight decay:1.1618752913853167e-06
# val acc:0.09 | lr:0.000380310598023386, weight decay:3.284297017258871e-08
# val acc:0.08 | lr:1.8943798802927938e-06, weight decay:1.0937338469153285e-06
# val acc:0.21 | lr:0.0009972484543148642, weight decay:1.2470442971496987e-07
# val acc:0.85 | lr:0.009973543548123201, weight decay:8.813662246103844e-08
# val acc:0.65 | lr:0.004452963472978943, weight decay:1.7507684605672808e-06
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.9) | lr:0.008500891870359345, weight decay:2.56318295699185e-07
# Best-2(val acc:0.87) | lr:0.009562381761641526, weight decay:9.888997842308008e-07
# Best-3(val acc:0.85) | lr:0.008159859380032067, weight decay:3.770768908538745e-05
# Best-4(val acc:0.85) | lr:0.008789937530045805, weight decay:2.710573539592424e-06
# Best-5(val acc:0.85) | lr:0.009973543548123201, weight decay:8.813662246103844e-08
# Best-6(val acc:0.83) | lr:0.00781913568403434, weight decay:1.311004986589884e-06
# Best-7(val acc:0.77) | lr:0.005053103251681211, weight decay:2.329193083311373e-05
# Best-8(val acc:0.74) | lr:0.004293624866585031, weight decay:1.641994001097466e-07
# Best-9(val acc:0.72) | lr:0.006145959809541509, weight decay:1.629539202515972e-08
# Best-10(val acc:0.68) | lr:0.00473870164338073, weight decay:1.8893786979773744e-05
# Best-11(val acc:0.65) | lr:0.005532082802440415, weight decay:1.9216075845887546e-08
# Best-12(val acc:0.65) | lr:0.004452963472978943, weight decay:1.7507684605672808e-06
# Best-13(val acc:0.64) | lr:0.00229396456420379, weight decay:4.11549959447376e-05
# Best-14(val acc:0.59) | lr:0.005022461048300095, weight decay:8.641098943371433e-07
# Best-15(val acc:0.58) | lr:0.0028344929115017648, weight decay:5.2286774556909086e-08
# Best-16(val acc:0.53) | lr:0.0046467826100957555, weight decay:3.4146427056790004e-07
# Best-17(val acc:0.44) | lr:0.001056814192840922, weight decay:8.590142565004911e-07
# Best-18(val acc:0.43) | lr:0.0022461087916804453, weight decay:8.594261342520517e-07
# Best-19(val acc:0.43) | lr:0.001409730659481814, weight decay:4.605428397219863e-05
# Best-20(val acc:0.34) | lr:0.0032034753943218203, weight decay:3.50355207448431e-06
