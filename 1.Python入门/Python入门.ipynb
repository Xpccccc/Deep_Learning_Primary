# %% [markdown]
# # Python 入门

# %% [markdown]
# ## Python 解释器

# %% [markdown]
# ### 算术运算

# %%
# 也可以用终端，在命令行输入python使用
1 - 2
# Out:
# -1

# %%
4*5
# Out:
# 20

# %%
7/5
# Out:
# 1.4

# %%
3**2
# Out:
# 9

# %% [markdown]
# ### 数据类型

# %%
type(10)
# Out:
# int

# %%
type(20.1)
# Out:
# float

# %%
type('hh')
# Out:
# str

# %% [markdown]
# ### 变量

# %%
x = 10
print (x)
# Out:
# 10

# %%
x = 100
print(x)
# Out:
# 100

# %%
y = 3.14
x * y
# Out:
# 314.0

# %%
type(x*y)
# Out:
# float

# %% [markdown]
# ### 列表

# %%
a = [1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a)
# Out:
# 5

# %%
a[0]
# Out:
# 1

# %%
a[4]
# Out:
# 5

# %%
a[4] = 99
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[1:]
# Out:
# [2, 3, 4, 99]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[:-1]
# Out:
# [1, 2, 3, 4]

# %%
a[:-2]
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 字典

# %%
me = {'height':180}
me['height']
# Out:
# 180

# %%
me['weight'] = 70
print(me)
# Out:
# {'height': 180, 'weight': 70}

# %% [markdown]
# ### 布尔型

# %%
hungry = True
sleepy = False
type(hungry)
# Out:
# bool

# %%
hungry and sleepy
# Out:
# False

# %%
hungry or sleepy
# Out:
# True

# %% [markdown]
# ### if 语句

# %%
hungry = True
if hungry:
    print("I'm hungry")
# Out:
# I'm hungry

# %%
hungry = False
if hungry:
    print("I'm hungry")
else:
    print("I'm not hungry")
    print("I'm sleepy")
# Out:
# I'm not hungry
# I'm sleepy

# %% [markdown]
# ### for 语句

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### 函数

# %%
def hello():
    print("hello World!")

# %%
hello()
# Out:
# hello World!

# %%
def hello(object):
    print("Hello " + object + "!")

# %%
hello('cat')
# Out:
# Hello cat!

# %% [markdown]
# ## Python 脚本文件

# %%
## cd 到 .py文件路径下，执行命令行 python python文件 就行了

# %% [markdown]
# ### 类

# %%
class Man:
    def __init__(self,name):
        self.name = name
        print("Inititalized!")
    def hello(self):
        print("Hello " + self.name + "!")
    def goodbye(self):
        print("Good-bye " + self.name + "!")

# %%
m = Man("David")
m.hello()
m.goodbye()
# Out:
# Inititalized!
# Hello David!
# Good-bye David!

# %% [markdown]
# ## Numpy

# %% [markdown]
# ### 导入 Numpy

# %%
import numpy as np

# %% [markdown]
# ### 生成 Numpy 数组

# %%
x = np.array([1.0,2.0,3.0])
print(x)
# Out:
# [1. 2. 3.]

# %%
type(x)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Numpy 的算术运算

# %%
x = np.array([1.0,2.0,3.0])
y = np.array([2.0,4.0,6.0])
x + y
# Out:
# array([3., 6., 9.])

# %%
x - y
# Out:
# array([-1., -2., -3.])

# %%
x * y
# Out:
# array([ 2.,  8., 18.])

# %%
x / y
# Out:
# array([0.5, 0.5, 0.5])

# %%
x = np.array([1.0,2.0,3.0])
x / 2.0
# Out:
# array([0.5, 1. , 1.5])

# %% [markdown]
# ### Numpy 的 N 维数组

# %%
A = np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int64')

# %%
B = np.array([[3,0],[0,6]])
A + B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A * B  # 对应元素相乘
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
A.dot(B)  # 点积
# Out:
# array([[ 3, 12],
#        [ 9, 24]])

# %%
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
 A*10
# Out:
# array([[10, 20],
#        [30, 40]])

# %% [markdown]
# ### 广播

# %%
A = np.array([[1,2],[3,4]])
B = np.array([10,20])
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# ### 访问元素

# %%
X = np.array([[51,55],[14,19],[0,4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X = X.flatten()
print(X)
# Out:
# [51 55 14 19  0  4]

# %%
X[np.array([0,2,4])]
# Out:
# array([51, 14,  0])

# %%
X > 15
# Out:
# array([ True,  True, False,  True, False, False])

# %%
X[X>15]
# Out:
# array([51, 55, 19])

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### 绘制简单图形

# %%
import numpy as mp
import matplotlib.pyplot as plt

# 生成数据
x = np.arange(0,6,0.1)
y = np.sin(x)

# 绘制图形
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### pyplot 的功能

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成数据
x = np.arange(0,6,0.1)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1,label="sin")
plt.plot(x,y2,linestyle = "--",label="cos")
plt.xlabel('x')
plt.ylabel('y')
plt.title('sin & cos')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 显示图像

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('风景1.jpg')
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
